# %% [markdown]
# # Mobile Project

# %%
import sys
def phone():
    print('welcome to python store')
    while True:
        option=str(input('\n do u want a phone?(yes/no): '))
        if option =='yes':
            print('\n great we have samsung and iphone')
            option1=input('select 1 brand (samsung/iphone): ')
            if option1=='samsung':
                print('here are the models: samsung20: ,samsung22: ,samsung24')
            elif option1=='iphone':
                print(' here are the models: iphone15:,iphone15promax: ,iphone15plus')
            else:
                print('\n sorry mobile is not availble. we ahve only samsung and iphone brand, thanks for you valuable time')
                break
        
            phone_selection=False
            while not phone_selection: 
                phone_selection = display_mobile_details()
                phone_selection1 = main()
        elif option =='no':
            print('okay, thank you')
            break
        else:
            print('we are sorry,choose yes or no')
            for inp in range(3):
                inp =input('choose yes or no: ')
                if inp == 'yes':
                    return phone()
                else:
                    print('sorry,its not a valid response thank you')
                    pass
        break
    sys.exit()
        


mobiles= {"samsung20":{"colour":["grey","white","black"],
                    "varient":["128gb","256gb","512gb"],
                    "ram":["6gb","8gb"],
                    "battary":["3000mh","4000mh"],                    
                    "camera":"duel camera",
                    "processor":"helio",
                    "display":"6.2inch",
                    "screen size":"6.1",
                    "weight":"165g",
                    "charger in box":"including in box",
                    "price":65000},
        
          "samsung22":{"colour":["grey","white","black"],
                    "varient":["128gb","256gb","512gb"],
                    "ram":["6gb","8gb"],
                    "battary":["3000mh","4000mh"],
                    "camera":"duel camera",
                    "processor":"helio",
                    "display":"6.2inch",
                    "screen size":"6.1",
                    "weight":"165g",
                    "charger in box":"including in box",
                    "price":70000},
        
          "samsung24":{"colour":["grey","white","black"],
                    "varient":["128gb","256gb","512gb"],
                    "ram":["6gb","8gb"],
                    "battary":["3000mh","4000mh"],
                    "camera":"duel camera",
                    "processor":"helio",
                    "display":"6.2inch",
                    "screen size":"6.1",
                    "weight":"165g",
                    "charger in box":"including in box",
                    "price":79000},
         
          "iphone15":{"colour":["grey","white","black"],
                    "varient":["128gb","256gb","512gb"],
                    "ram":["6gb","8gb"],
                    "battary":["3000mh","4000mh"],
                    "camera":"duel camera",
                    "processor":"a16 bionic",
                    "display":"6.5inch",
                    "screen size":"6.3",
                    "weight":"170g",
                    "charger in box":"including in box",
                    "price":120000},
         
          "iphone15plus":{"colour":["grey","white","black"],
                    "varient":["128gb","256gb","512gb"],
                    "ram":["6gb","8gb"],
                    "battary":["3000mh","4000mh"],
                    "camera":"duel camera",
                    "processor":"a16 bionic",
                    "display":"6.5inch",
                    "screen size":"6.3",
                    "weight":"170g",
                    "charger in box":"including in box",
                    "price":130000},
         
          "iphone15promax":{"colour":["grey","white","black"],
                    "varient":["128gb","256gb","512gb"],
                    "ram":["6gb","8gb"],
                    "battary":["3000mh","4000mh"],
                    "camera":"duel camera",
                    "processor":"a16 bionic",
                    "display":"6.5inch",
                    "screen size":"6.3",
                    "weight":"170g",
                    "charger in box":"including in box",
                    "price":140000}
          
          
         }

def display_mobile_details():
    
    mobile_name = str(input("\n Enter mobile model name: "))
    if mobile_name in mobiles:
        details = mobiles[mobile_name]
        print(f"colour:{details['colour']} ")
        print(f"varient:{details['varient']}")
        print(f"ram: {details['ram']}")
        print(f"battary:{details['battary']} ")
        print(f"camera:{details['camera']} ")
        print(f"processor:{details['processor']} ")
        print(f"display:{details['display']} ")
        print(f"screen size:{details['screen size']} ")
        print(f"weight: {details['weight']}")
        print(f"charger in box:{details['charger in box']} ")
        print(f"price:{details['price']} ")
    else:
        print("Mobile not available!")
        for _ in range(3):
            option1=user_inp=input('please consider another mobile: ')
            if option1=='samsung20'and 'samsung22' and 'samsung24' and 'iphone15' and 'iphone15plus' and 'iphone15promax':
                print('we have')
                return display_mobile_details()
            else:
                pass
        print('options are closed. we dont have that mobile. please visit again')
        sys.exit()
        
    
def main():
    while True:
        print("\n1. Display mobile details")
        print("2.Exit")
        choice = int(input("Enter your choice: "))
        if choice == 1:
            #display_mobile_details()
            mobile_name = str(input("Enter mobile model name you want: "))
            if mobile_name in mobiles:
                details = mobiles[mobile_name]
                print('\n')
                print('which colour?')
                print(' we have white grey and black')
                colour=str(input("colour: "))
                if colour=='white' or colour=='grey' or colour=='black':
                    print('great')
                else:
                    print('we dont have')
                    colour1 =input('choose the colour in above mentioned:')
                    if colour1=='white' or colour1=='grey' or colour1=='black':
                        print('great')
                    else:
                        print('sorry we dont have that colour but thanks for showing intrest and please visit again')
                        break
                print('\n')        
                print('which varient?')
                print('we have-128gb,256gb,512gb')
                varient=input("varient: ")
                if varient == '128gb' or varient=='256gb' or varient=='512gb':
                    print('great')
                else:
                    print('sorry we dont have')
                    varient1 = input('please choose the varient that we have: ')
                    if varient1 == '128gb' or varient1=='256gb' or varient1=='512gb':
                        print('great,we have')
                    else:
                        print('sorry we dont have that varient but thanks for showing intrest and please visit again')
                        break
                print('\n')
                print('how much ram?')
                print('we have 8gb,6gb')
                ram=input("ram: ")
                if ram == '6gb' or ram=='8gb':
                    print('great')
                else:
                    print('sorry we dont have')
                    ram1 = input('please choose the ram that we have: ')
                    if ram1 == '6gb' or ram1=='8gb':
                        print('great')
                    else:
                        print('sorry we dont have that ram but thanks for showing intrest and please visit again')
                        break
                print('\n')
                print('battery storage?')
                print('we have 3000mh,4000mh')
                battary=input("battary: ")
                if battary == '3000mh' or battary=='4000mh':
                    print('great,we have')
                else:
                    print('sorry we dont have')
                    battary1 = input('please choose the battry that we have: ')
                    if battary1 == '3000mh' or battary1=='4000mh':
                        print('great,we have')
                    else:
                        print('sorry we dont have that battary but thanks for showing intrest and please visit again')
                        break
                print('\n')
                print('camera?')
                print('we have duel camera')
                camera =str(input("camera: "))
                if camera == 'duel camera':
                    print('great')
                else:
                    print('sorry we dont have')
                    camera1 = input('please choose the ram that we have: ')
                    if camera1 == 'duel camera':
                        print('great')
                    else:
                        print('sorry we dont have that camera but thanks for showing intrest and please visit again')
                        break
                print('\n')
                print('processor?')
                print('we have helio for samsung and a16 bionic for iphone')
                processor=str(input("processor: "))
                if processor == 'helio' or processor=='a16bionic':
                    print('great')
                else:
                    print('sorry we dont have')
                    processor1 = input('please choose the processor that we have: ')
                    if processor1 == 'helio' or processorr1=='a16bionic':
                        print('great')
                    else:
                        print('sorry we dont have that processor but thanks for showing intrest and please visit again')
                        break
                print('\n')
                print('display size?')
                print('we have 6.2 inch for samsung and 6.5 inch for iphone')
                display=input("display: ")
                if display == '6.2' or display=='6.5':
                    print('great')
                else:
                    print('sorry we dont have')
                    display1 = input('please choose the display that we have: ')
                    if display1 == '6.2' or display1=='6.5':
                        print('great')
                    else:
                        print('sorry we dont have that display but thanks for showing intrest and please visit again')
                        break
                print('\n')
                print('screen size?')
                print('we have 6.1 for samsung and 6.3 for iphone ')
                size=(input("screen size: "))
                if size ==6.1 or size== 6.3:
                    print('great')
                else:
                    print('sorry we dont have')
                    size1 = input('please choose the screen size that we have: ')
                    if size1 == '6.1' or size1=='6.3':
                        print('great')
                    else:
                        print('sorry we dont have that screensize but thanks for showing intrest and please visit again')
                        break
                print('\n')
                print('weight?')
                print('we have 170g for iphone and 165g for samsung')
                weight=input("weight: ")
                if weight == '165g' or weight=='170g':
                    print('great')
                else:
                    print('sorry we dont have')
                    weight1 = input('please choose the weight that we have: ')
                    if weight1 == '165g' or weight1=='170g':
                        print('great')
                    else:
                        print('sorry we dont have that weight but thanks for showing intrest and please visit again')
                        break
                print('\n')
                print('which type of charger?')
                print('we have including in the box only')
                charger=str(input("charger box: "))
                if charger == 'including in the box':
                    print('great')
                else:
                    print('sorry we dont have')
                    charger1 = input('please choose the charger that we have: ')
                    if charger1 == 'including in the box':
                        print('great')
                    else:
                        print('sorry we dont have that charger but thanks for showing intrest and please visit again')
                        print('thanks for your valuable time ')
                        break
                print('\n')
                print("thank you for your purchase! we hope you love it")
                break
        elif choice == 2:
            print('Exit,thanks for visiting and please let us know if you change your mind')
            break
        else:
            print("Invalid choice!")
            for inp in range(3):
                inp=int(input('please enter valid choice: '))
                if inp == 1:
                    return main()
                else:
                    pass
            print('thanks for visiting and please visit again' )
            break
    sys.exit()

# %%
phone()
display_mobile_details()
main()
# Out:
# welcome to python store
#
#  do u want a phone?(yes/no): yes
#
#  great we have samsung and iphone
# select 1 brand (samsung/iphone): samsung
# here are the models: samsung20: ,samsung22: ,samsung24
#
#  Enter mobile model name: samsung20
# colour:['grey', 'white', 'black']
# varient:['128gb', '256gb', '512gb']
# ram: ['6gb', '8gb']
# battary:['3000mh', '4000mh']
# camera:duel camera
# processor:helio
# display:6.2inch
# screen size:6.1
# weight: 165g
# charger in box:including in box
# price:65000
#
# 1. Display mobile details
# 2.Exit
# Enter your choice: 1
# Enter mobile model name you want: samsung22
#
#
# which colour?
#  we have white grey and black
# colour: grey
# great
#
#
# which varient?
# we have-128gb,256gb,512gb
# varient: 128gb
# great
#
#
# how much ram?
# we have 8gb,6gb
# ram: 8gb
# great
#
#
# battery storage?
# we have 3000mh,4000mh
# battary: 300mh
# sorry we dont have
# please choose the battry that we have: 3000mh
# great,we have
#
#
# camera?
# ...

# %% [markdown]
# ##
